# %% [markdown]
# # Assemble
#
# This notebook loads and assembles all your basic data sources, including tabulor and geospatial data.
#
# The final output is two dataframes:
#
# - UNIVERSE
# - SALES
#
# The SALES dataframe represents transactions or parcels; these are ownership transfers with prices, dates, and metadata.
# The UNIVERSE dataframe represents the parcels themselves (land and buildings, and their associated characteristics).
#
# These will be packaged together in a handy data structure called a `SalesUniversePair`, or `sup` for short. `openavmkit` provides many handy functions that carefully perform operations on `sup`s without mixing up their fields.
#
# The key thing to understand is that the **Assemble** notebook outputs a `sup` that represents *factual assertions* about the world. In later notebooks, we will have to add assumptions, opinions, and educated guesses, but we first will establish the firmest facts we can in this notebook.
#
# You can think of the two dataframes in the `sup` as answering the following questions:
#
# - UNIVERSE:
#   - Where is each parcel located in space, and what is its shape?
#   - What are the *current* characteristics of each parcel?
#     - Which parcels have buildings and which are vacant lots?
#     - How big is each parcel?
#     - What is the age/size/quality/condition/etc of each building?
# - SALES:
#   - Which parcels have sold?
#   - What prices did they sell for?
#   - What dates did they sell on?
#   - Which sales were valid?
#   - What characteristics were different *at the time of sale* from how the parcel is now?

# %%
# Change these as desired

# The slug of the locality you are currently working on
locality = "us-ky-louisville"

# Whether to print out a lot of stuff (can help with debugging) or stay mostly quiet
verbose = True

# Clear previous state for this notebook and start fresh
clear_checkpoints = True

# %% [markdown]
# # 1. Basic setup

# %%
import init_notebooks
init_notebooks.setup_environment()
locality = init_notebooks.check_for_different_locality(locality)
# Out:
# Environment setup completed.

# %%
# import OpenAVMkit:
from openavmkit.pipeline import ( 
    init_notebook,
    from_checkpoint,
    delete_checkpoints,
    examine_df,
    examine_df_in_ridiculous_detail,
    examine_sup,
    examine_sup_in_ridiculous_detail,
    cloud_sync,
    load_settings,
    load_dataframes,
    process_dataframes,
    process_sales,
    enrich_sup_streets,
    tag_model_groups_sup,
    write_notebook_output_sup
)

# %%
init_notebook(locality)
# Out:
# locality = us-nc-guilford
# base path = C:\Users\jacks\Documents\Non-Game Stuff\Programming\openavmkit\notebooks\pipeline
# current path = C:\Users\jacks\Documents\Non-Game Stuff\Programming\openavmkit\notebooks\pipeline\data\us-nc-guilford

# %%
if clear_checkpoints:
    delete_checkpoints("1-assemble")

# %% [markdown]
# # 2. Sync with Cloud
# - If you have configured cloud storage, syncs with your remote storage
# - Reconciles your local input files with the versions on the remote server
# - Pulls down whatever is newer from the remote server
# - Uploads whatever is newer from your local machine

# %%
cloud_sync(locality, verbose=True)
# Out:
# Cloud access was None, defaulting to 'read_only'...
# Initializing cloud service of type 'azure' with access 'read_only'...
# _init_service('azure', 'read_only')
# ignore_paths = ['cloud.json']
# Syncing files from local="in" to remote="us/nc/guilford/"...
# Local file 'in/building.csv' missing for remote file 'us/nc/guilford/building.csv'. Downloading...
# Downloading 'in/building.csv' <-- 'us/nc/guilford/building.csv'...
# Local file 'in/caprates.csv' missing for remote file 'us/nc/guilford/caprates.csv'. Downloading...
# Downloading 'in/caprates.csv' <-- 'us/nc/guilford/caprates.csv'...
# Downloading 'in/invalid_sales.csv' <-- 'us/nc/guilford/invalid_sales.csv'...
# Local file 'in/noise.csv' missing for remote file 'us/nc/guilford/noise.csv'. Downloading...
# Downloading 'in/noise.csv' <-- 'us/nc/guilford/noise.csv'...
# Local file 'in/osm/streets.parquet' missing for remote file 'us/nc/guilford/osm/streets.parquet'. Downloading...
# Downloading 'in/osm/streets.parquet' <-- 'us/nc/guilford/osm/streets.parquet'...
# Local file 'in/parcels.csv' missing for remote file 'us/nc/guilford/parcels.csv'. Downloading...
# Downloading 'in/parcels.csv' <-- 'us/nc/guilford/parcels.csv'...
# Local file 'in/ref_zoning.csv' missing for remote file 'us/nc/guilford/ref_zoning.csv'. Downloading...
# Downloading 'in/ref_zoning.csv' <-- 'us/nc/guilford/ref_zoning.csv'...
# Local file 'in/sale.csv' missing for remote file 'us/nc/guilford/sale.csv'. Downloading...
# Downloading 'in/sale.csv' <-- 'us/nc/guilford/sale.csv'...
# Local file 'in/settings.json' missing for remote file 'us/nc/guilford/settings.json'. Downloading...
# Downloading 'in/settings.json' <-- 'us/nc/guilford/settings.json'...
# Local file 'in/slope.csv' missing for remote file 'us/nc/guilford/slope.csv'. Downloading...
# Downloading 'in/slope.csv' <-- 'us/nc/guilford/slope.csv'...

# %%
settings = load_settings()

# %% [markdown]
# # 3. Load & process data

# %%
# load all of our initial dataframes, but don't do anything with them just yet
dataframes = from_checkpoint("1-assemble-01-load_dataframes", load_dataframes,
    {
        "settings": load_settings(),
        "verbose": verbose
    }
)
# Out:
# Loading "in/parcels.csv"...
# --> rows = 219384
# Loading "in/sale.csv"...
# Valid sales: 114200 out of 220125 total
# UserWarning: No NA handling specified for boolean field 'valid_sale'. Defaulting to 'na_false'.
# UserWarning: No NA handling specified for boolean field 'vacant_sale'. Defaulting to 'na_false'.
# --> rows = 219957
# Loading "in/building.csv"...
# --> rows = 174179
# Loading "in/elevation.csv"...
# --> rows = 219373
# Loading "in/slope.csv"...
# --> rows = 219373
# Loading "in/noise.csv"...
# --> rows = 219373
# Loading "in/ref_zoning.csv"...
# --> rows = 204
# Loading "in/geo/parcels.parquet"...
# --> rows = 219382
# Loading "in/geo/census_tracts.parquet"...
# --> rows = 126
# Loading "in/geo/census_block_groups.parquet"...
# --> rows = 338
# Loading "in/geo/city.parquet"...
# --> rows = 20
# Loading "in/geo/zoning.parquet"...
# --> rows = 211
# Loading "in/geo/school_district.parquet"...
# --> rows = 8
# Loading "in/geo/golf_courses.parquet"...
# ensure_geometries, default crs = OGC:CRS84
# --> rows = 12
# Loading "in/geo/lakes.parquet"...
# --> rows = 11
# Loading "in/geo/central_business_district.parquet"...
# ensure_geometries, default crs = OGC:CRS84
# --> rows = 1
# Loading "in/geo/airport.parquet"...
# --> rows = 1
# Loading "in/geo/universities.parquet"...
# ensure_geometries, default crs = OGC:CRS84
# --> rows = 7
# Loading "in/geo/colleges.parquet"...
# ensure_geometries, default crs = OGC:CRS84
# --> rows = 3
# Loading "in/geo/parks.parquet"...
# ensure_geometries, default crs = OGC:CRS84
# --> rows = 101

# %%
# load all of our initial dataframes and assemble our data
sales_univ_pair = from_checkpoint("1-assemble-02-process_data", process_dataframes,
    {
        "dataframes": dataframes,
        "settings": load_settings(), 
        "verbose": verbose
    }
)
# Out:
# UserWarning: Dropped 1 rows due to missing primary key.
# Valid sales: 114196 (51.9% of 219957 total)
# Enriching data...
# Performing spatial joins...
# --> census_tracts
# --> census_block_groups
# --> city
# --> zoning
# --> school_district
# Using "key" to merge shapefiles onto df
# Enriching with Overture building data...
# --> Current settings: {'enabled': True, 'cache': True, 'footprint': {'units': 'sqft'}}
# --> Bounding box: [-80.04696875  35.89955906 -79.53229945  36.25871445]
# --> Fetching data from Overture...
# --> Dataset columns: ['id', 'geometry', 'bbox', 'version', 'sources', 'level', 'subtype', 'class', 'height', 'names', 'has_parts', 'is_underground', 'num_floors', 'num_floors_underground', 'min_height', 'min_floor', 'facade_color', 'facade_material', 'roof_material', 'roof_shape', 'roof_direction', 'roof_orientation', 'roof_color', 'roof_height']
# --> Skipping unavailable columns: ['est_height']
# --> Counting batches...
# --> Found 241 batches
# Processing batches: 100%|████████████████████████████████████████████████████████| 241/241 [00:02<00:00, 80.48it/s]
# --> Found 217459 buildings
# --> Available columns: ['id', 'geometry', 'bbox', 'height', 'num_floors', 'num_floors_underground', 'subtype', 'class', 'sources', 'height_m_best', 'height_ft_best', 'floors_best', 'height_confidence', 'num_floors_confidence']
# --> Calculating building footprint areas...
# --> Using UTM CRS: EPSG:32617
# --> Saving buildings to cache: cache/overture\buildings_-80.04696875251265_35.89955906359216_-79.53229945143045_36.25871445429295.parquet
# --> Building columns = ['id' 'geometry' 'bbox' 'height' 'num_floors' 'num_floors_underground'
#  'subtype' 'class' 'sources' 'height_m_best' 'height_ft_best'
#  'floors_best' 'height_confidence' 'num_floors_confidence'
#  'bldg_area_footprint_sqm' 'bldg_area_footprint_sqft']
# UserWarning: `process.enrich.overture.footprint.field` not specified, defaulting to 'bldg_area_footprint_sqft'
# UserWarning: `process.enrich.overture.height.units` not specified, defaulting to ft'
# UserWarning: `process.enrich.overture.height.field` not specified, defaulting to 'bldg_height_ft'
# Calculating building footprint areas!
# --> Projected to equal area CRS...(5.09s)
# --> Calculated building footprint intersections with parcels...(1.44s)
# --> Found 278922 potential building-parcel intersections
# --> Calculated precise intersection areas...(21.34s)
# --> Aggregated building footprint areas...(0.09s)
# --> Finished up...(0.38s)
# --> Added building footprint areas to 219373 parcels
# --> Total building footprint area: 625,733,227 sqft
# --> Average building footprint area: 2,852 sqft
# --> Number of parcels with buildings: 184,712
# --> Saving intersection areas to cache: cache/overture\intersections_area_1690008.2952693105_782774.103934899_1843018.0420707166_914621.7529687285.parquet
# Calculating building heights & floors!
# --> CRS aligned...(0.75s)
# --> Spatial join done...(1.52s), rows=278,922
# --> Aggregated heights/floors...(0.18s)
# --> Finished...(0.14s)
# --> Saving to cache: cache/overture\intersections_height_1690008.2952693105_782774.103934899_1843018.0420707166_914621.7529687285.parquet
# Performing basic geometric enrichment...
# --> added latitude/longitude...(4.04s)
# C:\Users\jacks\Documents\Non-Game Stuff\Programming\openavmkit\openavmkit\data.py:2887: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   gdf["land_area_sqft"].combine_first(gdf["land_area_gis_sqft"])
# C:\Users\jacks\Documents\Non-Game Stuff\Programming\openavmkit\openavmkit\data.py:2889: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[  120.00138415  6329.73884681  1800.40014687 ... 16807.77800083
#    120.02168562 71687.99805612]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   gdf.loc[
# C:\Users\jacks\Documents\Non-Game Stuff\Programming\openavmkit\venv\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# --> calculated GIS area of each parcel...(3.50s)
# --> calculated parcel rectangularity...(6.97s)
# --> calculated parcel aspect ratios...(1.56s)
# --> identifying irregular parcels...
# ----> simplified geometry...(2.38s)
# ----> identified triangular parcels...(79.68s)
# ----> identified complex geometry...(4.49s)
# ----> identified elongated parcels...(0.00s)
# ----> finished up...(0.21s)
# --> identified irregular parcels (total)...(86.77s)
# --> calculated polar coordinates...(4.11s)
# Enriching with Census data...
# Getting Census Data...
# Performing spatial join with Census Data...
# Census block group matching: 219115 of 219373 records have valid census geoid (99.88%)
# Enriching with OpenStreetMap data...
# --> Getting cbd...
# Getting cbd from source file...
# --> Found 1 cbd
#
# Distance settings for cbd:
# max_distance: 26400
# unit: ft
#
# Calculating distance, id=cbd, max_distance=26400, unit=ft, max_distance (in meters)=8046.719742504968
# --> Getting airport...
# Getting airport from source file...
# --> Found 1 airport
#
# Distance settings for airport:
# max_distance: 5280
# unit: ft
#
# Calculating distance, id=airport, max_distance=5280, unit=ft, max_distance (in meters)=1609.3439485009937
# --> Getting colleges...
# Getting colleges from source file...
# --> Found 3 colleges
#
# Distance settings for colleges:
# max_distance: 5280
# unit: ft
#
# Calculating distance, id=colleges, max_distance=5280, unit=ft, max_distance (in meters)=1609.3439485009937
# --> Getting universities...
# Getting universities from source file...
# --> Found 6 universities
#
# Distance settings for universities:
# max_distance: 5280
# unit: ft
#
# Calculating distance, id=universities, max_distance=5280, unit=ft, max_distance (in meters)=1609.3439485009937
# --> Getting golf_courses...
# Getting golf_courses from source file...
# --> Found 12 golf courses
#
# Distance settings for golf_courses:
# max_distance: 5280
# unit: ft
#
# Calculating distance, id=golf_courses, max_distance=5280, unit=ft, max_distance (in meters)=1609.3439485009937
# Calculating distance, id=golf_courses_greensboro_country_club, max_distance=5280, unit=ft, max_distance (in meters)=1609.3439485009937
# Calculating distance, id=golf_courses_grandover_golf_course, max_distance=5280, unit=ft, max_distance (in meters)=1609.3439485009937
# Calculating distance, id=golf_courses_forest_oaks_golf_course, max_distance=5280, unit=ft, max_distance (in meters)=1609.3439485009937
# Calculating distance, id=golf_courses_country_hills_golf_course, max_distance=5280, unit=ft, max_distance (in meters)=1609.3439485009937
# Calculating distance, id=golf_courses_stoney_creek_golf_course, max_distance=5280, unit=ft, max_distance (in meters)=1609.3439485009937
# Calculating distance, id=golf_courses_sedgefield_country_club, max_distance=5280, unit=ft, max_distance (in meters)=1609.3439485009937
# Calculating distance, id=golf_courses_alamance_church_golf_course, max_distance=5280, unit=ft, max_distance (in meters)=1609.3439485009937
# Calculating distance, id=golf_courses_cardinal_country_club, max_distance=5280, unit=ft, max_distance (in meters)=1609.3439485009937
# Calculating distance, id=golf_courses_brookwood_golf_course, max_distance=5280, unit=ft, max_distance (in meters)=1609.3439485009937
# Calculating distance, id=golf_courses_greensboro_country_club_irving_park_golf_course, max_distance=5280, unit=ft, max_distance (in meters)=1609.3439485009937
# Calculating distance, id=golf_courses_high_point_country_club, max_distance=5280, unit=ft, max_distance (in meters)=1609.3439485009937
# Calculating distance, id=golf_courses_ironplay_golf_course, max_distance=5280, unit=ft, max_distance (in meters)=1609.3439485009937
# --> Getting lakes...
# Getting lakes from source file...
# --> Found 11 lakes
#
# Distance settings for lakes:
# max_distance: 5280
# unit: ft
#
# Calculating distance, id=lakes, max_distance=5280, unit=ft, max_distance (in meters)=1609.3439485009937
# --> Getting parks...
# Getting parks from source file...
# --> Found 73 parks
#
# Distance settings for parks:
# max_distance: 5280
# unit: ft
#
# Calculating distance, id=parks, max_distance=5280, unit=ft, max_distance (in meters)=1609.3439485009937
# Performing reference table joins...
# Performing reference table joins...
# ...out/1-assemble-sup.pickle
# ...out/look/1-assemble-universe.parquet
# ...out/look/1-assemble-sales.parquet
# ...out/look/1-assemble-sales-hydrated.parquet

# %%
# calculate street frontages
sales_univ_pair = from_checkpoint("1-assemble-03-enrich_streets", enrich_sup_streets,
    {
        "sup": sales_univ_pair,
        "settings":load_settings(), 
        "verbose":verbose
    }
)
# Out:
# Street enrichment disabled. To enable it, add `data.process.enrich.streets.enabled = true` to your settings file.

# %% [markdown]
# # 4. Inspect results
#
# ## 4.1 Examine
#
# - Run the next cell and look at the printed out results.
# - Note the "Non-zero" and "Non-null" columns in particular and make sure they're what you expect
# - This view is for a quick glance to get a good idea of what all your data is

# %%
examine_sup(sales_univ_pair, load_settings())
# Out:
# EXAMINING UNIVERSE...
#
#             FIELD                 TYPE     NON-ZERO    %    NON-NULL    %                    UNIQUE
# ============================== ========== ========== ===== ========== ===== ========================================
#              LAND
# ============================== ========== ========== ===== ========== ===== ========================================
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
#            NUMERIC
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
# assr_land_value                 Float64      277,198   98%    282,400  100%
# depth_ft_1                      float64      268,482   95%    282,400  100%
# depth_ft_2                      float64       97,037   34%    282,400  100%
# depth_ft_3                      float64       18,962    7%    282,400  100%
# depth_ft_4                      float64        7,204    3%    282,400  100%
# dist_to_road_ft_1               float64      260,972   92%    282,400  100%
# dist_to_road_ft_2               float64       80,585   29%    282,400  100%
# dist_to_road_ft_3               float64        9,627    3%    282,400  100%
# dist_to_road_ft_4               float64        1,648    1%    282,400  100%
# frontage_ft_1                   float64      268,482   95%    282,400  100%
# frontage_ft_2                   float64       97,037   34%    282,400  100%
# frontage_ft_3                   float64       18,962    7%    282,400  100%
# frontage_ft_4                   float64        7,204    3%    282,400  100%
# geom_aspect_ratio               float64      282,400  100%    282,400  100%
# geom_rectangularity_num         Float64      282,400  100%    282,400  100%
# geom_vertices                    int64       282,391  100%    282,400  100%
# land_area_gis_delta_percent     Float64      282,383  100%    282,400  100%
# land_area_gis_delta_sqft        float64      282,383  100%    282,400  100%
# land_area_gis_sqft              float64      282,400  100%    282,400  100%
# land_area_given_sqft            Float64      282,383  100%    282,400  100%
# land_area_somers_ft             float64      268,482   95%    282,400  100%
# land_area_sqft                  float64      282,400  100%    282,400  100%
# land_area_sqft_log              float64      282,400  100%    282,400  100%
# latitude                        float64      282,400  100%    282,400  100%
# latitude_norm                   float64      282,399  100%    282,400  100%
# longitude                       float64      282,400  100%    282,400  100%
# longitude_norm                  float64      282,399  100%    282,400  100%
# osm_frontage_motorway_ft        float64        1,036    0%    282,400  100%
# osm_frontage_primary_ft         float64       10,243    4%    282,400  100%
# osm_frontage_residential_ft     float64      231,975   82%    282,400  100%
# osm_frontage_secondary_ft       float64       13,884    5%    282,400  100%
# osm_frontage_service_ft         float64       60,482   21%    282,400  100%
# osm_frontage_tertiary_ft        float64       17,173    6%    282,400  100%
# osm_frontage_trunk_ft           float64          643    0%    282,400  100%
# osm_frontage_unclassified_ft    float64        2,406    1%    282,400  100%
# osm_road_angle_1                float64      268,482   95%    268,482   95%
# osm_road_angle_2                float64       97,037   34%     97,037   34%
# osm_road_angle_3                float64       18,962    7%     18,962    7%
# osm_road_angle_4                float64        7,204    3%      7,204    3%
# osm_total_frontage_ft           float64      268,482   95%    282,400  100%
# polar_angle                     float64      282,400  100%    282,400  100%
# polar_radius                    float64      282,400  100%    282,400  100%
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
#            BOOLEAN
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
# is_geom_complex                   bool         3,084    1%    282,400  100%                            [False, True]
# is_geom_elongated                 bool        17,816    6%    282,400  100%                            [False, True]
# is_geom_irregular                 bool        21,706    8%    282,400  100%                            [False, True]
# is_geom_triangular                bool         1,071    0%    282,400  100%                            [False, True]
# is_vacant                         bool        45,917   16%    282,400  100%                            [False, True]
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
#          CATEGORICAL
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
# land_class                       string      282,400  100%    282,400  100%                                       50
# neighborhood                     string      199,752   71%    199,752   71%                                      162
# osm_road_face_1                  object      268,482   95%    268,482   95%                                        9
# osm_road_face_2                  object       97,037   34%     97,037   34%                                        9
# osm_road_face_3                  object       18,962    7%     18,962    7%                                        9
# osm_road_face_4                  object        7,204    3%      7,204    3%                                        9
# osm_road_name_1                  object      268,482   95%    268,482   95%                                   12,862
# osm_road_name_2                  object       97,037   34%     97,037   34%                                   23,192
# osm_road_name_3                  object       18,962    7%     18,962    7%                                   12,543
# osm_road_name_4                  object        7,204    3%      7,204    3%                                    6,596
# osm_road_type_1                  object      268,482   95%    268,482   95%                                       12
# osm_road_type_2                  object       97,037   34%     97,037   34%                                       14
# osm_road_type_3                  object       18,962    7%     18,962    7%                                       13
# osm_road_type_4                  object        7,204    3%      7,204    3%                                       12
# zoning                           string      238,164   84%    238,164   84%                                       63
#
# ============================== ========== ========== ===== ========== ===== ========================================
#          IMPROVEMENT
# ============================== ========== ========== ===== ========== ===== ========================================
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
#            NUMERIC
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
# assr_impr_value                 Float64      234,617   83%    282,400  100%
# bldg_area_finished_sqft         Float64      236,483   84%    282,400  100%
# bldg_condition_num              Float64        6,308    2%    282,400  100%
# bldg_effective_age_years        Float64      224,641   80%    282,400  100%
# bldg_effective_year_built       Float64      224,999   80%    270,916   96%
# bldg_rooms_bath_full            Float64      236,188   84%    282,400  100%
# bldg_stories                    Float64            4    0%     45,936   16%
# bldg_units                      Float64        4,995    2%     50,912   18%
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
#          CATEGORICAL
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
# bldg_ac                         category     282,400  100%    282,400  100%                 ['No', 'UNKNOWN', 'Yes']
# bldg_condition_txt              category      52,225   18%     52,225   18%                                        7
# bldg_type                       category     282,400  100%    282,400  100%         ['Structure', 'UNKNOWN', 'Land']
#
# ============================== ========== ========== ===== ========== ===== ========================================
#             OTHER
# ============================== ========== ========== ===== ========== ===== ========================================
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
#            NUMERIC
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
# assr_market_value               Float64      279,514   99%    282,400  100%
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
#            BOOLEAN
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
# is_vacant                         bool        45,917   16%    282,400  100%                            [False, True]
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
#          CATEGORICAL
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
# key                              string      282,400  100%    282,400  100%                                  282,400
# property_owner                   string      282,288  100%    282,288  100%                                  222,222
#
# ============================== ========== ========== ===== ========== ===== ========================================
# UNCLASSIFIED:
# ============================== ========== ========== ===== ========== ===== ========================================
# address                          object      282,400  100%    282,400  100%                                  276,019
# geometry                        geometry     282,400  100%    282,400  100%                                  282,400
# property_owner_address           object      282,271  100%    282,271  100%                                  204,366
#
# EXAMINING SALES...
#
#             FIELD                 TYPE     NON-ZERO    %    NON-NULL    %                    UNIQUE
# ============================== ========== ========== ===== ========== ===== ========================================
#             OTHER
# ============================== ========== ========== ===== ========== ===== ========================================
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
#            NUMERIC
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
# sale_age_days                   Float64      237,834  100%    237,834  100%
# sale_day                        Float64      237,834  100%    237,834  100%
# sale_month                      Float64      237,834  100%    237,834  100%
# sale_price                      Float64      202,340   85%    237,834  100%
# sale_quarter                    Float64      237,834  100%    237,834  100%
# sale_year                       Float64      237,834  100%    237,834  100%
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
#            BOOLEAN
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
# vacant_sale                       bool        14,616    6%    237,834  100%                            [True, False]
# valid_sale                        bool       237,834  100%    237,834  100%                                   [True]
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
#          CATEGORICAL
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
# key                              string      237,834  100%    237,834  100%                                  237,834
# key_sale                         string      237,834  100%    237,834  100%                                  237,834
# sale_date                      datetime64[ns]    237,834  100%    237,834  100%                                    6,803
# sale_year_month                  string      237,834  100%    237,834  100%                                      309
# sale_year_quarter                string      237,834  100%    237,834  100%                                      103
#
# ============================== ========== ========== ===== ========== ===== ========================================
# UNCLASSIFIED:
# ============================== ========== ========== ===== ========== ===== ========================================
# geometry                        geometry     231,356   97%    231,356   97%                                  231,356
# sale_type                        string      105,515   44%    105,515   44%                                       15

# %% [markdown]
# ## 4.2 Examine in ridiculous detail
#
# - You've looked, now LOOK AGAIN. This cell will run `describe()` for each numeric field and `value_counts()` for each categorical field.
# - Use this info to decide which variables are useful/useless
# - Consult this readout when you build your modeling group filters

# %%
examine_sup_in_ridiculous_detail(sales_univ_pair, load_settings())
# Out:
# EXAMINING UNIVERSE...
#
#             FIELD                 TYPE     NON-ZERO    %    NON-NULL    %                    UNIQUE
# ============================== ========== ========== ===== ========== ===== ========================================
#              LAND
# ============================== ========== ========== ===== ========== ===== ========================================
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
#            NUMERIC
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
# assr_land_value                                                              Float64      213,051   97%    219,373  100%
# DESCRIBE --> count         219373.0
# mean      81052.698281
# std      350385.522831
# min                0.0
# 25%            25000.0
# 50%            44000.0
# 75%            67200.0
# max         44808700.0
# Name: assr_land_value, dtype: Float64
#
#
# dist_to_airport                                                              float64        6,604    3%      8,195    4%
# DESCRIBE --> count    8195.000000
# mean     2235.026918
# std      1735.951493
# min         0.000000
# 25%       471.629048
# 50%      2182.651789
# 75%      3717.288789
# max      5279.816917
# Name: dist_to_airport, dtype: float64
#
#
# dist_to_cbd                                                                  float64       76,785   35%     78,077   36%
# DESCRIBE --> count    78077.000000
# mean     14858.079907
# std       7231.455682
# min          0.000000
# 25%       9083.493237
# 50%      15544.180152
# 75%      21082.282848
# max      26399.651502
# Name: dist_to_cbd, dtype: float64
#
#
# dist_to_colleges                                                             float64       16,428    7%     16,518    8%
# DESCRIBE --> count    16518.000000
# mean      3115.802933
# std       1450.946083
# min          0.000000
# 25%       2054.976640
# 50%       3296.926000
# 75%       4364.055231
# max       5279.948310
# Name: dist_to_colleges, dtype: float64
#
#
# dist_to_golf_courses                                                         float64       36,055   16%     37,445   17%
# DESCRIBE --> count    37445.000000
# mean      2682.239982
# std       1581.199502
# min          0.000000
# 25%       1358.863248
# 50%       2764.280267
# 75%       4058.512174
# max       5279.991845
# Name: dist_to_golf_courses, dtype: float64
#
#
# dist_to_golf_courses_alamance_church_golf_course                             float64          429    0%        440    0%
# DESCRIBE --> count     440.000000
# mean     3307.314902
# std      1524.085714
# min         0.000000
# 25%      2329.981060
# 50%      3648.430425
# 75%      4569.119486
# max      5268.625847
# Name: dist_to_golf_courses_alamance_church_golf_course, dtype: float64
#
#
# dist_to_golf_courses_brookwood_golf_course                                   float64          430    0%        444    0%
# DESCRIBE --> count     444.000000
# mean     2844.404246
# std      1554.789780
# min         0.000000
# 25%      1780.191307
# 50%      2984.952431
# 75%      4180.305410
# max      5274.116175
# Name: dist_to_golf_courses_brookwood_golf_course, dtype: float64
#
#
# dist_to_golf_courses_cardinal_country_club                                   float64        4,163    2%      4,304    2%
# DESCRIBE --> count    4304.000000
# mean     2389.651515
# std      1535.172615
# min         0.000000
# 25%      1051.580001
# 50%      2346.762350
# 75%      3681.394777
# max      5279.444906
# Name: dist_to_golf_courses_cardinal_country_club, dtype: float64
#
#
# dist_to_golf_courses_country_hills_golf_course                               float64          814    0%        858    0%
# DESCRIBE --> count     858.000000
# mean     2808.328501
# std      1667.889912
# min         0.000000
# 25%      1301.691336
# 50%      3124.655500
# 75%      4263.370538
# max      5272.601387
# Name: dist_to_golf_courses_country_hills_golf_course, dtype: float64
#
#
# dist_to_golf_courses_forest_oaks_golf_course                                 float64        2,498    1%      2,784    1%
# DESCRIBE --> count    2784.000000
# mean     1944.369745
# std      1575.920128
# min         0.000000
# 25%       588.138242
# 50%      1614.719403
# 75%      3154.445759
# max      5278.847746
# Name: dist_to_golf_courses_forest_oaks_golf_course, dtype: float64
#
#
# dist_to_golf_courses_grandover_golf_course                                   float64        3,195    1%      3,383    2%
# DESCRIBE --> count    3383.000000
# mean     2421.467830
# std      1638.235421
# min         0.000000
# 25%       873.963578
# 50%      2546.941168
# 75%      3751.221639
# max      5279.731433
# Name: dist_to_golf_courses_grandover_golf_course, dtype: float64
#
#
# dist_to_golf_courses_greensboro_country_club                                 float64        8,261    4%      8,451    4%
# DESCRIBE --> count    8451.000000
# mean     3035.734230
# std      1526.850694
# min         0.000000
# 25%      1798.236069
# 50%      3324.779935
# 75%      4346.682464
# max      5279.991845
# Name: dist_to_golf_courses_greensboro_country_club, dtype: float64
#
#
# dist_to_golf_courses_greensboro_country_club_irving_park_golf_course         float64        6,679    3%      6,728    3%
# DESCRIBE --> count    6728.000000
# mean     2938.417237
# std      1522.699128
# min         0.000000
# 25%      1623.249722
# 50%      3014.076980
# 75%      4316.547780
# max      5279.510924
# Name: dist_to_golf_courses_greensboro_country_club_irving_park_golf_course, dtype: float64
#
#
# dist_to_golf_courses_high_point_country_club                                 float64        5,171    2%      5,203    2%
# DESCRIBE --> count    5203.000000
# mean     3175.821170
# std      1371.104080
# min         0.000000
# 25%      2131.091617
# 50%      3299.800209
# 75%      4377.154645
# max      5279.572129
# Name: dist_to_golf_courses_high_point_country_club, dtype: float64
#
#
# dist_to_golf_courses_ironplay_golf_course                                    float64          668    0%        679    0%
# DESCRIBE --> count     679.000000
# mean     3481.183138
# std      1276.223877
# min         0.000000
# 25%      2665.118861
# 50%      3771.467285
# 75%      4519.006620
# max      5269.265179
# Name: dist_to_golf_courses_ironplay_golf_course, dtype: float64
#
#
# dist_to_golf_courses_sedgefield_country_club                                 float64        4,013    2%      4,177    2%
# DESCRIBE --> count    4177.000000
# mean     2944.235855
# std      1510.213192
# min         0.000000
# 25%      1802.985857
# 50%      3201.495021
# 75%      4177.991435
# max      5279.633207
# Name: dist_to_golf_courses_sedgefield_country_club, dtype: float64
#
#
# dist_to_golf_courses_stoney_creek_golf_course                                float64        2,625    1%      2,885    1%
# DESCRIBE --> count    2885.000000
# mean     1731.674795
# std      1331.033562
# min         0.000000
# 25%       423.172927
# 50%      1679.894045
# 75%      2613.543652
# max      5269.197294
# Name: dist_to_golf_courses_stoney_creek_golf_course, dtype: float64
#
#
# dist_to_lakes                                                                float64       44,068   20%     44,497   20%
# DESCRIBE --> count    44497.000000
# mean      2869.365407
# std       1492.165336
# min          0.000000
# 25%       1639.580265
# 50%       2978.076534
# 75%       4172.934758
# max       5279.964527
# Name: dist_to_lakes, dtype: float64
#
#
# dist_to_parks                                                                float64       84,586   39%     85,276   39%
# DESCRIBE --> count    85276.000000
# mean      2289.679426
# std       1481.489698
# min          0.000000
# 25%       1006.830678
# 50%       2123.840420
# 75%       3472.057068
# max       5279.937896
# Name: dist_to_parks, dtype: float64
#
#
# dist_to_universities                                                         float64       22,490   10%     22,903   10%
# DESCRIBE --> count    22903.000000
# mean      2861.649851
# std       1445.334280
# min          0.000000
# 25%       1774.254462
# 50%       2977.448571
# 75%       4042.033698
# max       5279.918735
# Name: dist_to_universities, dtype: float64
#
#
# elevation_mean                                                               Float64      219,373  100%    219,373  100%
# DESCRIBE --> count      219373.0
# mean     248.938731
# std        20.21723
# min      167.248162
# 25%      238.363997
# 50%      251.360728
# 75%      262.634693
# max      304.166386
# Name: elevation_mean, dtype: Float64
#
#
# elevation_stdev                                                              Float64      219,277  100%    219,373  100%
# DESCRIBE --> count     219373.0
# mean      1.025329
# std       1.115548
# min            0.0
# 25%       0.376288
# 50%       0.683206
# 75%       1.225112
# max      34.234903
# Name: elevation_stdev, dtype: Float64
#
#
# geom_aspect_ratio                                                            float64      219,373  100%    219,373  100%
# DESCRIBE --> count    219373.000000
# mean          1.956308
# std           1.470433
# min           1.000000
# 25%           1.086722
# 50%           1.729962
# 75%           2.361577
# max         226.395558
# Name: geom_aspect_ratio, dtype: float64
#
#
# geom_rectangularity_num                                                      Float64      219,372  100%    219,373  100%
# DESCRIBE --> count     219373.0
# mean      0.784707
# std       0.410052
# min     -25.665112
# 25%           0.72
# 50%       0.917238
# 75%       0.982579
# max            1.0
# Name: geom_rectangularity_num, dtype: Float64
#
#
# geom_vertices                                                                 int64       217,620   99%    219,373  100%
# DESCRIBE --> count    219373.000000
# mean          5.713260
# std           2.624102
# min           0.000000
# 25%           5.000000
# 50%           5.000000
# 75%           5.000000
# max         253.000000
# Name: geom_vertices, dtype: float64
#
#
# land_area_gis_delta_percent                                                  Float64      217,766   99%    219,373  100%
# DESCRIBE --> count      219373.0
# mean       0.002188
# std        1.366854
# min       -1.002114
# 25%       -0.000612
# 50%        0.000052
# 75%        0.000288
# max      634.033585
# Name: land_area_gis_delta_percent, dtype: Float64
#
#
# land_area_gis_delta_sqft                                                     float64      217,766   99%    219,373  100%
# DESCRIBE --> count    2.193730e+05
# mean     9.865563e+04
# std      2.236384e+07
# min     -2.003151e+09
# 25%     -1.564035e+01
# 50%      5.707051e-01
# 75%      8.725781e+00
# max      2.152024e+09
# Name: land_area_gis_delta_sqft, dtype: float64
#
#
# land_area_gis_sqft                                                           float64      219,373  100%    219,373  100%
# DESCRIBE --> count    2.193730e+05
# mean     7.650870e+04
# std      4.336554e+05
# min      4.748728e+00
# 25%      8.412364e+03
# 50%      1.405375e+04
# 75%      3.769636e+04
# max      7.571138e+07
# Name: land_area_gis_sqft, dtype: float64
#
#
# land_area_given_sqft                                                         Float64      217,766   99%    217,924   99%
# DESCRIBE --> count               217924.0
# mean           2610619.55742
# std         530062787.652562
# min                      0.0
# 25%              8496.574564
# 50%             14173.783015
# 75%                  38332.8
# max      198087105412.250183
# Name: land_area_given_sqft, dtype: Float64
#
#
# land_area_sqft                                                               float64      219,373  100%    219,373  100%
# DESCRIBE --> count    2.193730e+05
# mean    -2.214692e+04
# std      2.237245e+07
# min     -2.147484e+09
# 25%      8.381000e+03
# 50%      1.407000e+04
# 75%      3.791600e+04
# max      2.003197e+09
# Name: land_area_sqft, dtype: float64
#
#
# land_area_sqft_log                                                           float64      219,354  100%    219,354  100%
# DESCRIBE --> count    219354.000000
# mean          9.739414
# std           1.497872
# min           2.994377
# 25%           9.033961
# 50%           9.551942
# 75%          10.543498
# max          21.418010
# Name: land_area_sqft_log, dtype: float64
#
#
# latitude                                                                     float64      219,373  100%    219,373  100%
# DESCRIBE --> count    219373.000000
# mean         36.067665
# std           0.077024
# min          35.900106
# 25%          36.012242
# 50%          36.066049
# 75%          36.124246
# max          36.257191
# Name: latitude, dtype: float64
#
#
# latitude_norm                                                                float64      219,372  100%    219,373  100%
# DESCRIBE --> count    219373.000000
# mean          0.469242
# std           0.215702
# min           0.000000
# 25%           0.314031
# 50%           0.464715
# 75%           0.627696
# max           1.000000
# Name: latitude_norm, dtype: float64
#
#
# longitude                                                                    float64      219,373  100%    219,373  100%
# DESCRIBE --> count    219373.000000
# mean        -79.842525
# std           0.122411
# min         -80.046488
# 25%         -79.945955
# 50%         -79.839031
# 75%         -79.765544
# max         -79.532420
# Name: longitude, dtype: float64
#
#
# longitude_norm                                                               float64      219,372  100%    219,373  100%
# DESCRIBE --> count    219373.000000
# mean          0.396763
# std           0.238122
# min           0.000000
# 25%           0.195564
# 50%           0.403560
# 75%           0.546511
# max           1.000000
# Name: longitude_norm, dtype: float64
#
#
# median_c_rent                                                                float64      165,465   75%    165,465   75%
# DESCRIBE --> count    165465.000000
# mean        936.851866
# std         345.588896
# min          99.000000
# 25%         701.000000
# 50%         891.000000
# 75%        1099.000000
# max        3501.000000
# Name: median_c_rent, dtype: float64
#
#
# median_g_rent                                                                float64      166,189   76%    166,189   76%
# DESCRIBE --> count    166189.000000
# mean       1153.843696
# std         355.302871
# min          99.000000
# 25%         925.000000
# 50%        1104.000000
# 75%        1310.000000
# max        3501.000000
# Name: median_g_rent, dtype: float64
#
#
# median_income                                                                float64      210,217   96%    210,217   96%
# DESCRIBE --> count    210217.000000
# mean      77990.532378
# std       38143.423244
# min        2499.000000
# 25%       48012.000000
# 50%       71964.000000
# 75%       96607.000000
# max      217232.000000
# Name: median_income, dtype: float64
#
#
# noise_max                                                                    Float64       53,196   24%     53,196   24%
# DESCRIBE --> count       53196.0
# mean      53.424904
# std        6.191372
# min        45.00053
# 25%       48.168381
# 50%       52.720438
# 75%       57.616204
# max      105.612228
# Name: noise_max, dtype: Float64
#
#
# noise_mean                                                                   Float64       53,196   24%     53,196   24%
# DESCRIBE --> count      53196.0
# mean      50.23841
# std       3.808174
# min       45.00053
# 25%      47.173981
# 50%      49.589671
# 75%      52.739133
# max      79.135715
# Name: noise_mean, dtype: Float64
#
#
# polar_angle                                                                  float64      219,373  100%    219,373  100%
# DESCRIBE --> count    219373.000000
# mean         26.243039
# std           0.774461
# min          23.548115
# 25%          25.770835
# 50%          26.197735
# 75%          26.683294
# max          28.818012
# Name: polar_angle, dtype: float64
#
#
# polar_radius                                                                 float64      219,373  100%    219,373  100%
# DESCRIBE --> count    219373.000000
# mean     592431.542453
# std       11414.535286
# min      568753.953613
# 25%      584281.838269
# 50%      593017.388677
# 75%      599698.631538
# max      625919.368488
# Name: polar_radius, dtype: float64
#
#
# proximity_to_airport                                                         float64        8,194    4%    219,373  100%
# DESCRIBE --> count    219373.000000
# mean        113.742594
# std         667.793359
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max        5279.816917
# Name: proximity_to_airport, dtype: float64
#
#
# proximity_to_cbd                                                             float64       78,076   36%    219,373  100%
# DESCRIBE --> count    219373.000000
# mean       4107.758409
# std        7010.579426
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%        6267.133742
# max       26399.651502
# Name: proximity_to_cbd, dtype: float64
#
#
# proximity_to_colleges                                                        float64       16,517    8%    219,373  100%
# DESCRIBE --> count    219373.000000
# mean        162.952384
# std         696.138739
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max        5279.948310
# Name: proximity_to_colleges, dtype: float64
#
#
# proximity_to_golf_courses                                                    float64       37,444   17%    219,373  100%
# DESCRIBE --> count    219373.000000
# mean        443.412902
# std        1175.592140
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max        5279.991845
# Name: proximity_to_golf_courses, dtype: float64
#
#
# proximity_to_golf_courses_alamance_church_golf_course                        float64          439    0%    219,373  100%
# DESCRIBE --> count    219373.000000
# mean          3.933833
# std         111.123425
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max        5268.625847
# Name: proximity_to_golf_courses_alamance_church_golf_course, dtype: float64
#
#
# proximity_to_golf_courses_brookwood_golf_course                              float64          443    0%    219,373  100%
# DESCRIBE --> count    219373.000000
# mean          4.917616
# std         129.637581
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max        5274.116175
# Name: proximity_to_golf_courses_brookwood_golf_course, dtype: float64
#
#
# proximity_to_golf_courses_cardinal_country_club                              float64        4,303    2%    219,373  100%
# DESCRIBE --> count    219373.000000
# mean         56.696452
# std         454.813391
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max        5279.444906
# Name: proximity_to_golf_courses_cardinal_country_club, dtype: float64
#
#
# proximity_to_golf_courses_country_hills_golf_course                          float64          857    0%    219,373  100%
# DESCRIBE --> count    219373.000000
# mean          9.638133
# std         185.811255
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max        5272.601387
# Name: proximity_to_golf_courses_country_hills_golf_course, dtype: float64
#
#
# proximity_to_golf_courses_forest_oaks_golf_course                            float64        2,783    1%    219,373  100%
# DESCRIBE --> count    219373.000000
# mean         42.316907
# std         413.305247
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max        5278.847746
# Name: proximity_to_golf_courses_forest_oaks_golf_course, dtype: float64
#
#
# proximity_to_golf_courses_grandover_golf_course                              float64        3,382    2%    219,373  100%
# DESCRIBE --> count    219373.000000
# mean         44.077921
# std         406.718194
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max        5279.731433
# Name: proximity_to_golf_courses_grandover_golf_course, dtype: float64
#
#
# proximity_to_golf_courses_greensboro_country_club                            float64        8,450    4%    219,373  100%
# DESCRIBE --> count    219373.000000
# mean         86.456497
# std         525.694957
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max        5279.991845
# Name: proximity_to_golf_courses_greensboro_country_club, dtype: float64
#
#
# proximity_to_golf_courses_greensboro_country_club_irving_park_golf_course    float64        6,727    3%    219,373  100%
# DESCRIBE --> count    219373.000000
# mean         71.799530
# std         483.771439
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max        5279.510924
# Name: proximity_to_golf_courses_greensboro_country_club_irving_park_golf_course, dtype: float64
#
#
# proximity_to_golf_courses_high_point_country_club                            float64        5,202    2%    219,373  100%
# DESCRIBE --> count    219373.000000
# mean         49.895914
# std         383.481952
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max        5279.572129
# Name: proximity_to_golf_courses_high_point_country_club, dtype: float64
#
#
# proximity_to_golf_courses_ironplay_golf_course                               float64          678    0%    219,373  100%
# DESCRIBE --> count    219373.000000
# mean          5.534445
# std         122.062806
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max        5269.265179
# Name: proximity_to_golf_courses_ironplay_golf_course, dtype: float64
#
#
# proximity_to_golf_courses_sedgefield_country_club                            float64        4,176    2%    219,373  100%
# DESCRIBE --> count    219373.000000
# mean         44.467436
# std         381.167736
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max        5279.633207
# Name: proximity_to_golf_courses_sedgefield_country_club, dtype: float64
#
#
# proximity_to_golf_courses_stoney_creek_golf_course                           float64        2,884    1%    219,373  100%
# DESCRIBE --> count    219373.000000
# mean         46.522372
# std         430.931038
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max        5269.197294
# Name: proximity_to_golf_courses_stoney_creek_golf_course, dtype: float64
#
#
# proximity_to_lakes                                                           float64       44,496   20%    219,373  100%
# DESCRIBE --> count    219373.000000
# mean        488.959120
# std        1179.503375
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max        5279.964527
# Name: proximity_to_lakes, dtype: float64
#
#
# proximity_to_parks                                                           float64       85,275   39%    219,373  100%
# DESCRIBE --> count    219373.000000
# mean       1162.391367
# std        1725.653791
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%        2430.391953
# max        5279.937896
# Name: proximity_to_parks, dtype: float64
#
#
# proximity_to_universities                                                    float64       22,902   10%    219,373  100%
# DESCRIBE --> count    219373.000000
# mean        252.472329
# std         874.581450
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max        5279.918735
# Name: proximity_to_universities, dtype: float64
#
#
# slope_mean                                                                   Float64      219,373  100%    219,373  100%
# DESCRIBE --> count     219373.0
# mean     89.984034
# std       0.083399
# min      51.630409
# 25%      89.981846
# 50%      89.988089
# 75%      89.991672
# max      89.998706
# Name: slope_mean, dtype: Float64
#
#
# slope_stdev                                                                  Float64      219,238  100%    219,373  100%
# DESCRIBE --> count     219373.0
# mean      0.010605
# std       0.099471
# min            0.0
# 25%       0.001997
# 50%       0.004132
# 75%       0.009782
# max      43.581966
# Name: slope_stdev, dtype: Float64
#
#
# within_airport                                                                 bool         8,195    4%    219,373  100%
# DESCRIBE --> count     219373
# unique         2
# top        False
# freq      211178
# Name: within_airport, dtype: object
#
#
# within_cbd                                                                     bool        78,077   36%    219,373  100%
# DESCRIBE --> count     219373
# unique         2
# top        False
# freq      141296
# Name: within_cbd, dtype: object
#
#
# within_colleges                                                                bool        16,518    8%    219,373  100%
# DESCRIBE --> count     219373
# unique         2
# top        False
# freq      202855
# Name: within_colleges, dtype: object
#
#
# within_golf_courses                                                            bool        37,445   17%    219,373  100%
# DESCRIBE --> count     219373
# unique         2
# top        False
# freq      181928
# Name: within_golf_courses, dtype: object
#
#
# within_golf_courses_alamance_church_golf_course                                bool           440    0%    219,373  100%
# DESCRIBE --> count     219373
# unique         2
# top        False
# freq      218933
# Name: within_golf_courses_alamance_church_golf_course, dtype: object
#
#
# within_golf_courses_brookwood_golf_course                                      bool           444    0%    219,373  100%
# DESCRIBE --> count     219373
# unique         2
# top        False
# freq      218929
# Name: within_golf_courses_brookwood_golf_course, dtype: object
#
#
# within_golf_courses_cardinal_country_club                                      bool         4,304    2%    219,373  100%
# DESCRIBE --> count     219373
# unique         2
# top        False
# freq      215069
# Name: within_golf_courses_cardinal_country_club, dtype: object
#
#
# within_golf_courses_country_hills_golf_course                                  bool           858    0%    219,373  100%
# DESCRIBE --> count     219373
# unique         2
# top        False
# freq      218515
# Name: within_golf_courses_country_hills_golf_course, dtype: object
#
#
# within_golf_courses_forest_oaks_golf_course                                    bool         2,784    1%    219,373  100%
# DESCRIBE --> count     219373
# unique         2
# top        False
# freq      216589
# Name: within_golf_courses_forest_oaks_golf_course, dtype: object
#
#
# within_golf_courses_grandover_golf_course                                      bool         3,383    2%    219,373  100%
# DESCRIBE --> count     219373
# unique         2
# top        False
# freq      215990
# Name: within_golf_courses_grandover_golf_course, dtype: object
#
#
# within_golf_courses_greensboro_country_club                                    bool         8,451    4%    219,373  100%
# DESCRIBE --> count     219373
# unique         2
# top        False
# freq      210922
# Name: within_golf_courses_greensboro_country_club, dtype: object
#
#
# within_golf_courses_greensboro_country_club_irving_park_golf_course            bool         6,728    3%    219,373  100%
# DESCRIBE --> count     219373
# unique         2
# top        False
# freq      212645
# Name: within_golf_courses_greensboro_country_club_irving_park_golf_course, dtype: object
#
#
# within_golf_courses_high_point_country_club                                    bool         5,203    2%    219,373  100%
# DESCRIBE --> count     219373
# unique         2
# top        False
# freq      214170
# Name: within_golf_courses_high_point_country_club, dtype: object
#
#
# within_golf_courses_ironplay_golf_course                                       bool           679    0%    219,373  100%
# DESCRIBE --> count     219373
# unique         2
# top        False
# freq      218694
# Name: within_golf_courses_ironplay_golf_course, dtype: object
#
#
# within_golf_courses_sedgefield_country_club                                    bool         4,177    2%    219,373  100%
# DESCRIBE --> count     219373
# unique         2
# top        False
# freq      215196
# Name: within_golf_courses_sedgefield_country_club, dtype: object
#
#
# within_golf_courses_stoney_creek_golf_course                                   bool         2,885    1%    219,373  100%
# DESCRIBE --> count     219373
# unique         2
# top        False
# freq      216488
# Name: within_golf_courses_stoney_creek_golf_course, dtype: object
#
#
# within_lakes                                                                   bool        44,497   20%    219,373  100%
# DESCRIBE --> count     219373
# unique         2
# top        False
# freq      174876
# Name: within_lakes, dtype: object
#
#
# within_parks                                                                   bool        85,276   39%    219,373  100%
# DESCRIBE --> count     219373
# unique         2
# top        False
# freq      134097
# Name: within_parks, dtype: object
#
#
# within_universities                                                            bool        22,903   10%    219,373  100%
# DESCRIBE --> count     219373
# unique         2
# top        False
# freq      196470
# Name: within_universities, dtype: object
#
#
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
#            BOOLEAN
# ------------------------------ ---------- ---------- ----- ---------- ----- ----------------------------------------
# 37081010401     855
# 37081014408     854
# 37081016010     836
# 37081012620     833
# 37081010701     824
# 37081010403     774
# 37081010702     722
# 37081010900     700
# 37081016005     695
# 37081012504     659
# 37081010100     649
# 37081011201     624
# 37081012618     552
# 37081012608     524
# 37081013601     522
# 37081980100     154
# Name: count, dtype: Int64
#
#
# city                                                                          string       60,953   28%     60,953   28%                                       14
# VALUE COUNTS --> city
# HIGH POINT         43739
# SUMMERFIELD         4958
# STOKESDALE          3425
# GIBSONVILLE         2555
# PLEASANT GARDEN     2346
# JAMESTOWN           1785
# BURLINGTON           838
# SEDALIA              583
# WHITSETT             444
# ARCHDALE             210
# KERNERSVILLE          68
# GREENSBORO             1
# OAK RIDGE              1
# Name: count, dtype: Int64
#
#
# land_class                                                                    string      219,345  100%    219,345  100%                                       37
# VALUE COUNTS --> land_class
# RESIDENTIAL             167828
# TOWNHOUSE                14581
# CONDO                     7787
# IND                       5251
# COMM                      4403
# VACANT                    3103
# AGRI/HORT                 3038
# COMMON AREA               2465
# GOV OWNED                 2236
# OFFICE                    1861
# DEVELOPMT RESTRICTED      1427
# INSTITUTIONAL             1074
# APART                      890
# MULTI-FAMILY<4             853
# RETAIL                     831
# AIRPORT                    296
# LEASED                     203
# SINGLE WIDE MH             171
# MFG HOM                    168
# REC/PARK                   144
# HOTEL/MOTEL                 91
# UTILITY USE                 88
# FUNERAL HM/CEMETERY         85
# SCHOOL/COLL/UNIV            81
# ASSIST LIV/SKILLCARE        81
# TWINHOME                    70
# MH PARK                     55
# QUARR                       41
# DRAINAGE LOT                35
# Unknown Owner               28
# GOLF COURSE                 25
# PETROL/GAS                  22
# MULTI-FAMILY5>              20
# RAILROAD CORRIDOR            6
# MED                          6
# NONE                         1
# Name: count, dtype: Int64
#
#
# neighborhood                                                                  string      218,485  100%    218,485  100%                                    2,991
# VALUE COUNTS --> neighborhood
# 8930R01-OSCEOLA HIGH ROCK RURAL ACREAGE                                    665
# 7855A05-GREEN VALLEY-STARMT FARMS                                          614
# 7881A04-FOREST OAKS                                                        579
# 8830A01-MT HOPE-KIMESVILLE AREA                                            548
# 6892A03-OAKVIEW ESTATES                                                    506
# 7875A01-P0RTER SCHOOL AREA                                                 487
# 7874B37-LOWDERMILK - KENTWOOD                                              481
# 8824A01-RIDGE CREEK TOWNHOMES                                              479
# 7802A01-OAK HOLLOW SUBDIVISIONS @ JOHNSON/CENTENNIAL                       471
# 7803A01-SOUTHWEST SCHOOL AREA                                              452
# 7826A07-RIVER HILLS PLANTATION                                             440
# 7845A03-HAMILTON FST-GREEN VALLEY                                          434
# 7813A06-NOTTINGHAM                                                         433
# 7824A01-CHARLESTOWNE SQ CONDOS                                             425
# 8805L01-NORTH BIRCH CREEK                                                  417
# 8824A02-BRIGHTWOOD FARMS PHASE I                                           415
# 7823A02-JAMESFORD MEADOWS                                                  414
# 8835A01-GIBSONVILLE I                                                      407
# 8805A01-BIRCH CREEK                                                        396
# 7855A08-FOREST VALLEY                                                      396
# 7844A03-HAMILTON VILLAGE TOWNHOME                                          392
# 2550      22
# 398       22
# 2847      22
# 2396      22
# 1193      22
# 1690      22
# 2681      22
# 2762      22
# 3096      22
# 2555      22
# 2901      22
# 2527      22
# 2417      22
# 2321      22
# 2936      22
# 2408      22
# 2727      22
# 2440      22
# 2846      22
# 3012      22
# 2763      21
# 2433      21
# 2203      21
# 2912      21
# 2636      21
# 2863      21
# 2209      21
# 1907      21
# 2264      21
# 2909      21
# 2670      21
# 2504      21
# 3034      21
# 9         21
# 2352      21
# 2510      21
# 2712      21
# 2816      21
# 3082      20
# 2897      20
# 4         20
# 2583      20
# 3027      20
# 2430      20
# 3039      20
# 2665      20
# 2214      20
# 105       20
# 2741      20
# 277       19
# 2889      19
# 3099      19
# 2509      19
# 2848      19
# 2694      19
# 3059      19
# 2838      18
# 2903      18
# 5         18
# 2967      18
# 2346      18
# 2819      18
# 2338      18
# 2374      18
# 2806      18
# 2621      17
# 2915      17
# 7         17
# 2600      17
# 2572      17
# 2230      16
# 2835      16
# 3046      16
# 2884      15
# 6         13
# 4480       1
# 7840       1
# 9861       1
# 9797       1
# 9160       1
# 4026       1
# 6640       1
# 5320       1
# 9340       1
# 7078       1
# 5860       1
# 5208       1
# 6575       1
# 22244      1
# 4736       1
# 9202       1
# 9910       1
# 9540       1
# 30600      1
# 3537       1
# Name: count, dtype: Int64
#
#
# key                                                                           string      114,196  100%    114,196  100%                                  114,188
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# ## 4.3 Look at it on a map
#
# - Go to your `out/look/` folder
# - There should be parquets there
# - Drop them into ArcGIS, QGIS, or Felt
# - Look at your location fields and make sure they make sense

# %% [markdown]
# # 5. Tag modeling groups
# - Separates rows into groups like "single family", "townhomes" and "commercial" as specified by the user
# - These groups will guide all further processing

# %%
sales_univ_pair = from_checkpoint("1-assemble-04-tag_modeling_groups", tag_model_groups_sup,
    {
        "sup": sales_univ_pair, 
        "settings": load_settings(), 
        "verbose": verbose
    }
)
# Out:
# Len univ before = 219373
# Len sales before = 114196 after = 114196
# Overall
# --> 219,373 parcels
# --> 114,196 sales
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Documents\Non-Game Stuff\Programming\openavmkit\venv\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'zoning_category'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 sales_univ_pair = from_checkpoint("1-assemble-04-tag_modeling_groups", tag_model_groups_sup,
#       2     {
#       3         "sup": sales_univ_pair,
#       4         "settings": load_settings(),
#       5         "verbose": verbose
#       6     }
#       7 )
#
# File ~\Documents\Non-Game Stuff\Programming\openavmkit\openavmkit\pipeline.py:1144, in from_checkpoint(path, func, params)
#    1122 def from_checkpoint(path: str, func: callable, params: dict) -> pd.DataFrame:
#    1123     """
#    1124     Read cached data from a checkpoint file or generate it via a function.
#    1125
#    (...)
#    1142         The resulting DataFrame, loaded from the checkpoint or generated.
#    1143     """
# -> 1144     return openavmkit.checkpoint.from_checkpoint(path, func, params)
#
# File ~\Documents\Non-Game Stuff\Programming\openavmkit\openavmkit\checkpoint.py:43, in from_checkpoint(path, func, params, use_checkpoint)
#      41     return read_checkpoint(path)
#      42 else:
# ---> 43     result = func(**params)
#      44     write_checkpoint(result, path)
#      45     return result
#
# File ~\Documents\Non-Game Stuff\Programming\openavmkit\openavmkit\pipeline.py:801, in tag_model_groups_sup(sup, settings, verbose)
#     778 def tag_model_groups_sup(
#     779     sup: SalesUniversePair, settings: dict, verbose: bool = False
#     780 ) -> SalesUniversePair:
#     781     """
#     782     Tag model groups for a SalesUniversePair.
#     783
#    (...)
#     799         Updated SalesUniversePair with tagged model groups.
#     800     """
# --> 801     return openavmkit.data._tag_model_groups_sup(sup, settings, verbose)
#
# File ~\Documents\Non-Game Stuff\Programming\openavmkit\openavmkit\data.py:4627, in _tag_model_groups_sup(sup, settings, verbose)
#    4622 if len(_filter) == 0:
#    4623     raise ValueError(
#    4624         "No 'filter' entry found for model group '{mg_id}'. Check your spelling!"
#    4625     )
# -> 4627 univ_index = resolve_filter(df_univ, _filter)
#    4628 df_univ.loc[idx_no_model_group & univ_index, "model_group"] = mg_id
#    4630 idx_no_model_group = df_sales_hydrated["model_group"].isnull()
#
# File ~\Documents\Non-Game Stuff\Programming\openavmkit\openavmkit\filters.py:140, in resolve_filter(df, f, rename_map)
#     138     return resolve_not_filter(df, f)
#     139 elif _is_bool_operator(operator):
# --> 140     return resolve_bool_filter(df, f)
#     141 else:
#     142     field = f[1]
#
# File ~\Documents\Non-Game Stuff\Programming\openavmkit\openavmkit\filters.py:81, in resolve_bool_filter(df, f)
#      78 final_index = None
#      80 for v in values:
# ---> 81     selected_index = resolve_filter(df, v)
#      83     if final_index is None:
#      84         final_index = selected_index
#
# File ~\Documents\Non-Game Stuff\Programming\openavmkit\openavmkit\filters.py:140, in resolve_filter(df, f, rename_map)
#     138     return resolve_not_filter(df, f)
#     139 elif _is_bool_operator(operator):
# --> 140     return resolve_bool_filter(df, f)
#     141 else:
#     142     field = f[1]
#
# File ~\Documents\Non-Game Stuff\Programming\openavmkit\openavmkit\filters.py:81, in resolve_bool_filter(df, f)
#      78 final_index = None
#      80 for v in values:
# ---> 81     selected_index = resolve_filter(df, v)
#      83     if final_index is None:
#      84         final_index = selected_index
#
#     [... skipping similar frames: resolve_bool_filter at line 81 (1 times), resolve_filter at line 140 (1 times)]
#
# File ~\Documents\Non-Game Stuff\Programming\openavmkit\openavmkit\filters.py:140, in resolve_filter(df, f, rename_map)
#     138     return resolve_not_filter(df, f)
#     139 elif _is_bool_operator(operator):
# --> 140     return resolve_bool_filter(df, f)
#     141 else:
#     142     field = f[1]
#
# File ~\Documents\Non-Game Stuff\Programming\openavmkit\openavmkit\filters.py:81, in resolve_bool_filter(df, f)
#      78 final_index = None
#      80 for v in values:
# ---> 81     selected_index = resolve_filter(df, v)
#      83     if final_index is None:
#      84         final_index = selected_index
#
# File ~\Documents\Non-Game Stuff\Programming\openavmkit\openavmkit\filters.py:191, in resolve_filter(df, f, rename_map)
#     189     return df[field].ne(value)
#     190 if operator == "isin":
# --> 191     return df[field].isin(value)
#     192 if operator == "notin":
#     193     return ~df[field].isin(value)
#
# File ~\Documents\Non-Game Stuff\Programming\openavmkit\venv\Lib\site-packages\geopandas\geodataframe.py:1750, in GeoDataFrame.__getitem__(self, key)
#    1744 def __getitem__(self, key):
#    1745     """
#    1746     If the result is a column containing only 'geometry', return a
#    1747     GeoSeries. If it's a DataFrame with any columns of GeometryDtype,
#    1748     return a GeoDataFrame.
#    1749     """
# -> 1750     result = super().__getitem__(key)
#    1751     # Custom logic to avoid waiting for pandas GH51895
#    1752     # result is not geometry dtype for multi-indexes
#    1753     if (
#    1754         pd.api.types.is_scalar(key)
#    1755         and key == ""
#    (...)
#    1758         and not is_geometry_type(result)
#    1759     ):
#
# File ~\Documents\Non-Game Stuff\Programming\openavmkit\venv\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\Documents\Non-Game Stuff\Programming\openavmkit\venv\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'zoning_category'

# %% [markdown]
# # 6. Write out results

# %%
write_notebook_output_sup(
    sales_univ_pair, 
    "1-assemble", 
    parquet=True, 
    gpkg=False, 
    shp=False
)

# %% [markdown]
# # 7. Look at it on a map!
# - Take the files output in the previous step and put them in a map viewer like QGIS, ArcGIS, or Felt
# - Look at them with your eyeballs
# - Make sure the data looks correct
# - If not, go back and fix it!
# - Don't proceed to the next step until everything looks right
